# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("melbourne.csv")
df.head() #to predict the market price of a house from given attributes
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         23547 non-null  object
#  1   Address        23547 non-null  object
#  2   Rooms          23547 non-null  int64
#  3   Type           23547 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         23547 non-null  object
#  6   SellerG        23547 non-null  object
#  7   Date           23547 non-null  object
#  8   Distance       23546 non-null  float64
#  9   Postcode       23546 non-null  float64
#  10  Bedroom2       19066 non-null  float64
#  11  Bathroom       19063 non-null  float64
#  12  Car            18921 non-null  float64
#  13  Landsize       17410 non-null  float64
#  14  BuildingArea   10018 non-null  float64
#  15  YearBuilt      11540 non-null  float64
#  16  CouncilArea    15656 non-null  object
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  23547.000000  1.839600e+04  23546.000000  23546.000000  19066.000000
# mean       2.976048  1.056697e+06     10.306515   3109.782893      2.951956
# std        0.974501  6.419217e+05      6.016318     94.522190      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.330000e+05      6.200000   3047.000000      2.000000
# 50%        3.000000  8.800000e+05      9.500000   3101.000000      3.000000
# 75%        4.000000  1.302000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  19063.000000  18921.000000   17410.000000  10018.000000  11540.000000
# mean       1.570897      1.626235     551.783458    154.527895   1964.636742
# ...

# %%
#identifying missing values
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
df.isnull().all(axis=1).sum() #is there any row which is all blank
# Out:
# 0

# %%
df.isnull().sum(axis=1)
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
#         ..
# 23542    2
# 23543    8
# 23544    4
# 23545    1
# 23546    2
# Length: 23547, dtype: int64

# %%
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
#removing the columns
df=df.drop('BuildingArea',axis=1)
df=df.drop('YearBuilt',axis=1)
df=df.drop('CouncilArea',axis=1)

round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df[df.isnull().sum(axis=1)>5]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...                  ...                  ...    ...  ...        ...    ...
# 23495  Templestowe Lower  1/207 Manningham Rd      2    u   550000.0     PI
# 23499          Thornbury      1/128 Dundas St      2    t   770000.0     PI
# 23502          Thornbury        111 Pender St      2    t   858000.0      S
# 23508             Toorak   21/1059 Malvern Rd      2    u   720000.0     VB
# 23531           Werribee         91 Latham St      4    h   540000.0     PI
#
# ...

# %%
len(df[df.isnull().sum(axis=1)>5].index)
# Out:
# 4278

# %%
100*(len(df[df.isnull().sum(axis=1)>5].index)/len(df.index))
# Out:
# 18.16791948018856

# %%
#retaining the rows haveing 5 or less null values as 18% deletion wont affect the results
df=df[df.isnull().sum(axis=1)<=5]

round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
#20% of price column is sitll missing and it is the target column i.e I am not going to use it but will use other attributes to predict the prize.
df=df[~np.isnan(df.Price)]

round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         1.05
# Bathroom         1.07
# Car              1.76
# Landsize         9.83
# Lattitude        0.15
# Longtitude       0.15
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df["Landsize"].describe()
# the min is 0,max is 433333, the mean is 558 and median 440. the data looks skewed there's too much variation in 25th and 75 percentile as well
#thus imputing with with mean/median seems quite biased, so lets remove them
# Out:
# count     13603.000000
# mean        558.116371
# std        3987.326586
# min           0.000000
# 25%         176.500000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %%
df=df[~np.isnan(df.Landsize)]
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.16
# Longtitude       0.16
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Suburb            0
# Address           0
# Rooms             0
# Type              0
# Price             0
# Method            0
# SellerG           0
# Date              0
# Distance          0
# Postcode          0
# Bedroom2          0
# Bathroom          1
# Car              63
# Landsize          0
# Lattitude        22
# Longtitude       22
# Regionname        0
# Propertycount     0
# dtype: int64

# %%
df[["Lattitude","Longtitude"]].describe()
# Out:
#           Lattitude    Longtitude
# count  13581.000000  13581.000000
# mean     -37.809204    144.995221
# std        0.079257      0.103913
# min      -38.182550    144.431810
# 25%      -37.856820    144.929600
# 50%      -37.802360    145.000100
# 75%      -37.756400    145.058320
# max      -37.408530    145.526350

# %%
df[np.isnan(df["Lattitude"])]=df.Lattitude.mean()
df.isnull().sum()
# Out:
# Suburb            0
# Address           0
# Rooms             0
# Type              0
# Price             0
# Method            0
# SellerG           0
# Date              0
# Distance          0
# Postcode          0
# Bedroom2          0
# Bathroom          1
# Car              63
# Landsize          0
# Lattitude         0
# Longtitude        0
# Regionname        0
# Propertycount     0
# dtype: int64

# %%
#the distributuion of lat and long is quite narrow. A good way to estimate way to estimate the spread of data is to look at the difference b/w the mean and median(lower the better) and variation from 25 to 75 percentile(quite small in this case)
#thus I am imputing the missing values by the mean value of lat and long

df.loc[np.isnan(df["Lattitude"]),['Lattitude']]=df.Lattitude.mean()
df.loc[np.isnan(df["Longtitude"]),["Longtitude"]]=df.Longtitude.mean()
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0
# Address           0
# Rooms             0
# Type              0
# Price             0
# Method            0
# SellerG           0
# Date              0
# Distance          0
# Postcode          0
# Bedroom2          0
# Bathroom          1
# Car              63
# Landsize          0
# Lattitude         0
# Longtitude        0
# Regionname        0
# Propertycount     0
# dtype: int64

# %%
df[["Bathroom","Car"]].describe()
# Out:
#            Bathroom           Car
# count  13602.000000  13540.000000
# mean       1.534921      1.610414
# std        0.691834      0.962244
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        1.000000      2.000000
# 75%        2.000000      2.000000
# max        8.000000     10.000000

# %%
df['Car'].value_counts()
# Out:
# 2.0     5606
# 1.0     5515
# 0.0     1026
# 3.0      748
# 4.0      507
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: Car, dtype: int64

# %%
df.loc[pd.isnull(df['Car']),['Car']]=2
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.00
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df['Bathroom'].value_counts()
# Out:
# 1.0    7517
# 2.0    4987
# 3.0     921
# 4.0     106
# 0.0      34
# 5.0      28
# 6.0       5
# 8.0       2
# 7.0       2
# Name: Bathroom, dtype: int64

# %%
df.loc[pd.isnull(df['Bathroom']),['Bathroom']]=1

# %%
len(df.index)/23547
# Out:
# 0.5776956724848176
